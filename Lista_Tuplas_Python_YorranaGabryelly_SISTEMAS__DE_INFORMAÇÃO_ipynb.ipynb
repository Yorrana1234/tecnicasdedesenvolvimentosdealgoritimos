# %% [markdown]
# <a href="https://colab.research.google.com/github/Yorrana1234/tecnicasdedesenvolvimentosdealgoritimos/blob/main/Lista_Tuplas_Python_YorranaGabryelly_SISTEMAS__DE_INFORMA%C3%87%C3%83O_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Introdução
Listas
Exemplos Exercicios
'''
print()

# %%
lista1 = [10, 20, 30, 40]
lista2 = ["programação", "IFB", "python"]
lista3 = ["oi", 2.0, 5, [10, 20]]

# %%
nota1 = float(input("Entre com a nota 1: "))
nota2 = float(input("Entre com a nota 2: "))
nota3 = float(input("Entre com a nota 3: "))
# Out:
# Entre com a nota 1: 4
# Entre com a nota 2: 6
# Entre com a nota 3: 2

# %%
notas = [8.0, 5.5, 9.3, 7.6, 3.1]
print(notas[1])
print(notas[2])
print(notas[3])
print(notas[4])
print(type(notas), len(notas))
# Out:
# 5.5
# 9.3
# 7.6
# 3.1
# <class 'list'> 5

# %% [markdown]
# ## Aplicações com Listas, Tuplas e Dicionários.

# %%
alunos_db = [
  {"matricula": "2025001", "nome": "João Lucas", "curso": "Medicina"},
  {"matricula": "2025002", "nome": "Ana Julia", "curso": "Sistemas De Informação"},
  {"matricula": "2025003", "nome": "Lucas Silva", "curso": "Enfermagem"},
]
print("1. Sistemas Simplificado De Cadastro De Alunos")
print("-" * 40)

# 1. Adicionar Novo Aluno (CREATE)
print("-> Adicionando novo aluno...")
novo_aluno = {"matricula": "2025004", "nome": "Ana Clara", "curso": "Engenharia De Software"}
alunos_db.append(novo_aluno) #Adiciona o dicionario (novo_aluno) a lista alunos_db
print(f"Aluno {novo_aluno['nome']} adicionado com sucesso!")

# 2. Buscar Aluno por Matricula (READ)
matricula_busca = "2025005"
aluno_encontrado = next((aluno for aluno in alunos_db if aluno["matricula"] == matricula_busca), None)

if aluno_encontrado:
  print(f"\nAluno encontrado (matricula: {matricula_busca}):")
  # Acessa os valores do dicionario usando suas chaves.
  print(f"Nome: {aluno_encontrado['nome']}, Curso: {aluno_encontrado['curso']}")
else:
  print(f"\nAluno com matricula {matricula_busca} não encontrado.")

# 3. Atualizar Informações do Curso (UPDATE)
matricula_update = "2025003" # Changed to a matricula that exists in the initial list
for aluno in alunos_db:
  if aluno["matricula"] == matricula_update:
    aluno["curso"] = "Segurança da Informação"
    print(f"\nCurso do aluno {aluno['nome']} atualizado para: {aluno['curso']}")
    break
print("-" * 40)

# Display the updated list of students (optional)
print("\nLista de alunos atualizada:")
for aluno in alunos_db:
    print(aluno)
# Out:
# 1. Sistemas Simplificado De Cadastro De Alunos
# ----------------------------------------
# -> Adicionando novo aluno...
# Aluno Ana Clara adicionado com sucesso!
#
# Aluno com matricula 2025005 não encontrado.
#
# Curso do aluno Lucas Silva atualizado para: Segurança da Informação
# ----------------------------------------
#
# Lista de alunos atualizada:
# {'matricula': '2025001', 'nome': 'João Lucas', 'curso': 'Medicina'}
# {'matricula': '2025002', 'nome': 'Ana Julia', 'curso': 'Sistemas De Informação'}
# {'matricula': '2025003', 'nome': 'Lucas Silva', 'curso': 'Segurança da Informação'}
# {'matricula': '2025004', 'nome': 'Ana Clara', 'curso': 'Engenharia De Software'}

# %%
import random

# Definindo as seleções e seus potes (exemplo simplificado, baseado em um ranking hipotético)
# Em um cenário real, esta lista seria baseada no ranking oficial da FIFA e nas regras de distribuição dos potes.
pote1 = ["Brasil", "França", "Argentina", "Inglaterra", "Bélgica", "Portugal", "Espanha", "Itália"]
pote2 = ["Alemanha", "Holanda", "Croácia", "México", "EUA", "Suíça", "Uruguai", "Dinamarca"]
pote3 = ["Senegal", "Japão", "Irã", "Sérvia", "Coreia do Sul", "Polônia", "Marrocos", "Ucrânia"] # Exemplo, Ucrânia precisaria se classificar
pote4 = ["Austrália", "Costa Rica", "Canadá", "Arábia Saudita", "Catar", "Equador", "Gana", "Camarões"] # Exemplo, Catar como país sede

# Dicionário para armazenar a confederação de cada seleção (simplificado)
confederations = {
    "Brasil": "CONMEBOL", "Argentina": "CONMEBOL", "Uruguai": "CONMEBOL", "Equador": "CONMEBOL",
    "França": "UEFA", "Alemanha": "UEFA", "Espanha": "UEFA", "Inglaterra": "UEFA", "Portugal": "UEFA", "Bélgica": "UEFA", "Holanda": "UEFA", "Itália": "UEFA", "Croácia": "UEFA", "Suíça": "UEFA", "Dinamarca": "UEFA", "Polônia": "UEFA", "Sérvia": "UEFA", "Ucrânia": "UEFA", # Adicionado Ucrânia
    "México": "CONCACAF", "EUA": "CONCACAF", "Canadá": "CONCACAF", "Costa Rica": "CONCACAF",
    "Senegal": "CAF", "Marrocos": "CAF", "Tunísia": "CAF", "Gana": "CAF", "Camarões": "CAF",
    "Japão": "AFC", "Irã": "AFC", "Coreia do Sul": "AFC", "Arábia Saudita": "AFC", "Austrália": "AFC", "Catar": "AFC" # Adicionado Catar
}

# Lista de potes
potes = [pote1, pote2, pote3, pote4]

print("Seleções e potes definidos.")
# Out:
# Seleções e potes definidos.

# %% [markdown]
# EXERCICIOS LISTA TUPLAS

# %%
"TAREFA 01"
#SOLICITE 5 NÚMEROS INTEIROS AO USUARIO
num = []
for i in range(5) :
  numero_inteiro = int(input(f"Digite o{i+1} numero intero: "))
  num.append(numero_inteiro)
print("Lista dos numeros digitados:")
print(num)
# Out:
# Digite o1 numero intero: 40
# Digite o2 numero intero: 50
# Digite o3 numero intero: 60
# Digite o4 numero intero: 40
# Digite o5 numero intero: 50
# Lista dos numeros digitados:
# [40, 50, 60, 40, 50]

# %%
"TAREFA 02"
" Escreva um programa que aplica a função módulo a todos os elementos e uma lista. "
num = [-5, 3, -8, 0, 7, -2]
modulos = [abs(n) for n in num]

print("Lista original:", num)
print("Lista com valores absolutos:", modulos)
# Out:
# Lista original: [-5, 3, -8, 0, 7, -2]
# Lista com valores absolutos: [5, 3, 8, 0, 7, 2]

# %%
"TAREFA 03"
"Escreva um programa que aplica a função módulo a todos os elementos e uma lista."

num = [-5, 3, -8, 0, 7, -2, 10]
positivos = [n for n in num if n >= 0]

print("Lista original:", num)
print("Lista sem negativos:", positivos)
# Out:
# Lista original: [-5, 3, -8, 0, 7, -2, 10]
# Lista sem negativos: [3, 0, 7, 10]

# %%
"TAREFA 04"
"Faça um programa que solicita uma quantidade indefinida de notas de uma prova (deve parar quando um númeronegativo for digitado). Armazena em uma lista. Após isso, o programa deve mostrar a média das notas."

notas = []
while True:
  nota = float(input("Digite uma nota (ou número negativo para sair): "))
  if nota < 0:
    break
  notas.append(nota)

if len(notas) > 0:
    media = sum(notas) / len(notas)
    print(f"\nNotas digitadas: {notas}")
    print(f"Média das notas: {media:.2f}")
else:
    print("Nenhuma nota válida foi digitada.")
# Out:
# Digite uma nota (ou número negativo para sair): 4
# Digite uma nota (ou número negativo para sair): 10
# Digite uma nota (ou número negativo para sair): -7
#
# Notas digitadas: [4.0, 10.0]
# Média das notas: 7.00

# %%
"TAREFA 05"
"Faça um programa que solicita uma quantidade indefinida de números positivos (deve parar quando um número negativo for digitado). Armazene-os em duas listas:  uma para os números pares; outra para os números ímpares. A seguir, mostre a porcentagem de pares e ímpares digitados"

pares = []
impares = []

while True:
  num_str = input("Digite um número positivo (ou número negativo para encerrar): ")
  try:
    num = int(num_str)
    if num < 0:
      break
    if num % 2 == 0:
        pares.append(num)
    else:
        impares.append(num)
  except ValueError:
    print("Entrada inválida. Por favor, digite um número inteiro.")

total = len(pares) + len(impares)

print("\n--- Resultados ---")
if total > 0:
    perc_pares = (len(pares) / total) * 100
    perc_impares = (len(impares) / total) * 100

    print(f"Números pares: {pares}")
    print(f"Números ímpares: {impares}")
    print(f"Porcentagem de pares: {perc_pares:.2f}%")
    print(f"Porcentagem de ímpares: {perc_impares:.2f}%")
else:
    print("Nenhum número válido foi digitado.")
# Out:
# Digite um número positivo (ou número negativo para encerrar): 10
# Digite um número positivo (ou número negativo para encerrar): 50
# Digite um número positivo (ou número negativo para encerrar): -30
#
# --- Resultados ---
# Números pares: [10, 50]
# Números ímpares: []
# Porcentagem de pares: 100.00%
# Porcentagem de ímpares: 0.00%

# %%
"TAREFA 06"
"Faça um programa que solicita uma quantidade indefinida de números positivos (deve parar quando um número negativo for digitado). Armazene todos os números digitados em uma lista, sem repetição. Exercícios"
numeros = []
while True:
    try:
        num_str = input("Digite um número positivo (ou número negativo para encerrar): ")
        num = int(num_str)
        if num < 0:
            break
        if num >= 0 and num not in numeros:
            numeros.append(num)
    except ValueError:
        print("Entrada inválida. Por favor, digite um número inteiro.")

print("\n--- Resultados ---")
if len(numeros) > 0:
    print(f"Números digitados (sem repetição): {numeros}")
else:
    print("Nenhum número válido foi digitado.")
# Out:
# Digite um número positivo (ou número negativo para encerrar): 40
# Digite um número positivo (ou número negativo para encerrar): 50
# Digite um número positivo (ou número negativo para encerrar): 90
# Digite um número positivo (ou número negativo para encerrar): -10
#
# --- Resultados ---
# Números digitados (sem repetição): [40, 50, 90]

# %%
"TAREFA 07"
"Escreva um programa que solicita que o usuário digite a altura e o peso de 5 pessoas. Verifique se pelo menos duas das pessoas tem a mesma altura e mesmo peso"

pessoas = [] # Initialize the list 'pessoas' here
for i in range(1, 6):
    print(f"\nPessoa {i}:")
    altura = float(input("Digite a altura (em metros): "))
    peso = float(input("Digite o peso (em kg): "))
    pessoas.append((altura, peso)) # Append the tuple to the list

duplicado = False
for i in range(len(pessoas)):
    for j in range(i + 1, len(pessoas)):
        if pessoas[i] == pessoas[j]:
            duplicado = True
            break
    if duplicado:
        break

print("\n--- Resultado ---")
if duplicado:
    print("Há pelo menos duas pessoas com a mesma altura e o mesmo peso.")
else:
    print("Nenhuma combinação de altura e peso se repete entre as pessoas.")
# Out:
# Pessoa 1:
# Digite a altura (em metros): 100
# Digite o peso (em kg): 400
#
# Pessoa 2:
# Digite a altura (em metros): 500
# Digite o peso (em kg): 600
#
# Pessoa 3:
# Digite a altura (em metros): 600
# Digite o peso (em kg): 800
#
# Pessoa 4:
# Digite a altura (em metros): 400
# Digite o peso (em kg): 800
#
# Pessoa 5:
# Digite a altura (em metros): 800
# Digite o peso (em kg): 600
#
# --- Resultado ---
# Nenhuma combinação de altura e peso se repete entre as pessoas.

# %%
"TAREFA 08"
"Faça um programa que solicita que o usuário digite o nome e a idade de diversas pessoas (o programa deve parar quando um nome vazio for informado). Retorne o nome da pessoa mais velha."

pessoas = []
while True:
    nome = input("Digite o nome da pessoa : ").strip()
    if nome == "":
        break
    try:
        idade = int(input(f"Digite a idade de {nome}: "))
        pessoas.append((nome, idade))
    except ValueError:
        print("Entrada inválida para idade. Por favor, digite um número inteiro.")

if len(pessoas) == 0:
    print("\nNenhuma pessoa foi informada.")
else:1
mais_velha = max(pessoas, key=lambda p: p[1])
print(f"\nA pessoa mais velha é {mais_velha[0]}, com {mais_velha[1]} anos.")
# Out:
# Digite o nome da pessoa : Marcos
# Digite a idade de Marcos: 25
# Digite o nome da pessoa : Maria
# Digite a idade de Maria: 20
# Digite o nome da pessoa : Julia
# Digite a idade de Julia: 28
# Digite o nome da pessoa : Joao
# Digite a idade de Joao: 30
# Digite o nome da pessoa : Livia
# Digite a idade de Livia: 30
# Digite o nome da pessoa : Lucas
# Digite a idade de Lucas: 10
# Digite o nome da pessoa : Lara
# Digite a idade de Lara: 30
# Digite o nome da pessoa :
#
# A pessoa mais velha é Joao, com 30 anos.
